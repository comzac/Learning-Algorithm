# %%
# !pip install -q h5py pyyaml

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
import os

# %%
try:
  # Colab only
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow import keras

tf.__version__
# Out:
# TensorFlow 2.x selected.
# '2.0.0-rc0'

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_labels = train_labels[:1000]
test_labels = test_labels[:1000]

train_images = train_images[:1000].reshape(-1,28*28)/255.0
test_images = test_images[:1000].reshape(-1,28*28)/255.0

# %%
def create_model():
  model = tf.keras.models.Sequential([
      keras.layers.Dense(512, activation='relu', input_shape=(784,)),
      keras.layers.Dropout(0.2),
      keras.layers.Dense(10, activation ='softmax')                                
  ])

  model.compile(optimizer = 'adam',
                loss = 'sparse_categorical_crossentropy',
                metrics = ['accuracy'])
  
  return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !cd /content/gdrive/

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import os 

checkpoint_path = "/content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt" 

checkpoint_dir = os.path.dirname(checkpoint_path)

 # Create checkpoint  callback 
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,save_weights_only=True,verbose=1)

model.fit(train_images, train_labels,  epochs = 10,validation_data = (test_images,test_labels), callbacks = [cp_callback])
# Out:
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/10
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f18fa1128c8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f18fa1128c8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
#  896/1000 [=========================>....] - ETA: 0s - loss: 1.2521 - accuracy: 0.6295
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.1901 - accuracy: 0.6470 - val_loss: 0.7286 - val_accuracy: 0.7770
# Epoch 2/10
#  928/1000 [==========================>...] - ETA: 0s - loss: 0.4169 - accuracy: 0.8944
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 0s 309us/sample - loss: 0.4174 - accuracy: 0.8930 - val_loss: 0.5429 - val_accuracy: 0.8350
# Epoch 3/10
#  928/1000 [==========================>...] - ETA: 0s - loss: 0.3021 - accuracy: 0.9213
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 0s 351us/sample - loss: 0.2945 - accuracy: 0.9250 - val_loss: 0.4494 - val_accuracy: 0.8640
# Epoch 4/10
#  960/1000 [===========================>..] - ETA: 0s - loss: 0.2098 - accuracy: 0.9510
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 0s 316us/sample - loss: 0.2077 - accuracy: 0.9520 - val_loss: 0.4549 - val_accuracy: 0.8560
# Epoch 5/10
#  928/1000 [==========================>...] - ETA: 0s - loss: 0.1574 - accuracy: 0.9677
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 0s 323us/sample - loss: 0.1579 - accuracy: 0.9690 - val_loss: 0.4458 - val_accuracy: 0.8460
# Epoch 6/10
#  992/1000 [============================>.] - ETA: 0s - loss: 0.1172 - accuracy: 0.9819
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 0s 329us/sample - loss: 0.1167 - accuracy: 0.9820 - val_loss: 0.4136 - val_accuracy: 0.8650
# Epoch 7/10
#  896/1000 [=========================>....] - ETA: 0s - loss: 0.0785 - accuracy: 0.9944
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 0s 348us/sample - loss: 0.0833 - accuracy: 0.9930 - val_loss: 0.4134 - val_accuracy: 0.8620
# Epoch 8/10
#  928/1000 [==========================>...] - ETA: 0s - loss: 0.0640 - accuracy: 0.9957
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 0s 320us/sample - loss: 0.0639 - accuracy: 0.9960 - val_loss: 0.4096 - val_accuracy: 0.8650
# Epoch 9/10
#  960/1000 [===========================>..] - ETA: 0s - loss: 0.0490 - accuracy: 0.9958
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 0s 353us/sample - loss: 0.0500 - accuracy: 0.9960 - val_loss: 0.4123 - val_accuracy: 0.8640
# Epoch 10/10
#  864/1000 [========================>.....] - ETA: 0s - loss: 0.0374 - accuracy: 1.0000
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/checkpoint/cp.ckpt
# 1000/1000 [==============================] - 0s 318us/sample - loss: 0.0352 - accuracy: 1.0000 - val_loss: 0.4181 - val_accuracy: 0.8640

# %%
# !cd gdrive/

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
mkdir gdrive/My\ Drive/Colab\ Notebooks/checkpoint
# Out:
# mkdir: cannot create directory ‘gdrive/My Drive/Colab Notebooks/checkpoint’: File exists

# %%
# !ls gdrive/My\ Drive/Colab\ Notebooks/checkpoint
# Out:
# checkpoint		     cp.ckpt.data-00001-of-00002
# cp.ckpt.data-00000-of-00002  cp.ckpt.index

# %%
model = create_model()
loss, acc = model.evaluate(test_images, test_labels)
print("훈련되지 않은 모델의 정확도 : {:5.2f}%".format(100*acc))
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 훈련되지 않은 모델의 정확도 :  9.70%

# %%
model.load_weights(checkpoint_path)
loss, acc = model.evaluate(test_images, test_labels)
print("훈련되지 않은 모델의 정확도 : {:5.2f}%".format(100*acc))
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 훈련되지 않은 모델의 정확도 : 86.40%
