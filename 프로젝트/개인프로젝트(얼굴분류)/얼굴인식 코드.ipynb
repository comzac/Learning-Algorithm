# %%
import numpy as np
import cv2
import sys
import imutils

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
# eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# img = image('face_879.png')
image = cv2.imread('face_879.png')

# cv2.imshow('Images', img )
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(50, 50)
)

print('found {0} faces'.format(len(faces)))
# Out:
# found 1 faces

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]
#     eyes = eye_cascade.detectMultiScale(roi_gray)
#     for (ex,ey,ew,eh) in eyes:
#         cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)


#cv2.imwrite('detect_result.jpg',img)

# %%
test = image[y:y+h, x:x+w]
cv2.imwrite('detect_result.jpg',test)
# Out:
# True

# %%
import os
# Out:
# ['face_1009.png',
#  'face_101.png',
#  'face_1016.png',
#  'face_1027.png',
#  'face_1039.png',
#  'face_1055.png',
#  'face_1056.png',
#  'face_1059.png',
#  'face_1060.png',
#  'face_1079.png',
#  'face_1080.png',
#  'face_1084.png',
#  'face_1089.png',
#  'face_1118.png',
#  'face_1121.png',
#  'face_1147.png',
#  'face_115.png',
#  'face_1155.png',
#  'face_116.png',
#  'face_1181.png',
#  'face_1203.png',
#  'face_121.png',
#  'face_1223.png',
#  'face_1227.png',
#  'face_1253.png',
#  'face_1273.png',
#  'face_1275.png',
#  'face_1282.png',
#  'face_1289.png',
#  'face_1298.png',
#  'face_13.png',
#  'face_1310.png',
#  'face_1332.png',
#  'face_1340.png',
#  'face_1350.png',
#  'face_1351.png',
#  'face_1354.png',
#  'face_1363.png',
#  'face_1368.png',
#  'face_137.png',
#  'face_1377.png',
#  'face_1399.png',
#  'face_1449.png',
#  'face_1453.png',
#  'face_1456.png',
#  'face_1459.png',
#  'face_1477.png',
#  'face_1480.png',
#  'face_1508.png',
#  'face_1535.png',
# ...

# %%
for i in range(1, 2):
    path = '1st/data/test/{}/'.format(i)
    filelist = os.listdir(path)
    for filename in filelist:
        image = cv2.imread(path + filename)

        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(
                gray,
                scaleFactor=1.1,
                minNeighbors=5,
                minSize=(50, 50)
        )

        print('found {0} faces'.format(len(faces)))

        for (x,y,w,h) in faces:
            cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = image[y:y+h, x:x+w]
        #     eyes = eye_cascade.detectMultiScale(roi_gray)
        #     for (ex,ey,ew,eh) in eyes:
        #         cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)


        #cv2.imwrite('detect_result.jpg',img)

        test = image[y:y+h, x:x+w]
        finalfath = 'output/1stTest/{}/{}'.format(i, filename)
        cv2.imwrite(finalfath,test)
# Out:
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# found 1 faces
# ...
