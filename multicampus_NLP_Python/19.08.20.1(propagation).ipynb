# %% [markdown]
# # 전치행렬 등장 이유

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # back propagation (오류역전파) 정리

# %% [markdown]
# ### 난해했던 부분
# 1. 예제에서 d_l2의 의미는 l2의 미분이라기 보다는 최종 오류에 l2가 영향을 끼치는 정도를 파악하는 것도 아닌!! 역전파 과정에서 오류값에서 l2에 도달한 값이었다
# 2. d_w2에서 전치행렬이 등장하는 이유
#
# ### 아직 의아한 부분
# 3. wx+b에서 편의상 곱으로 나타냈지만 사실상 행렬곱인데, 그래서 역전파 과정에서도 행렬곱 연산으로 처리되는지?
# 4. 엄밀히 따지고 보면 편미분 순서가 곱셈상에서는 큰 문제가 없는데 행렬곱이라면 얘기가 달라진다. 이 부분에서 어떤 특성이 있는것인지?
#
# ![image.png](attachment:image.png)
