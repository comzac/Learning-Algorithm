# %%
pip install imutils
# Out:
# Collecting imutils
#   Downloading https://files.pythonhosted.org/packages/b5/94/46dcae8c061e28be31bcaa55c560cb30ee9403c9a4bb2659768ec1b9eb7d/imutils-0.5.3.tar.gz
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\LeeSunSoo\AppData\Local\pip\Cache\wheels\16\84\1f\bf88641293cda2c8be81a5c4b8ca973dd9125a6dc3767417fd
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import imutils
import cv2
import numpy as np

# %%
image = cv2.imread("face_9.png")

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image_gray_blurred = cv2.GaussianBlur(image_gray, (5, 5), 0)

# %%
ret,thresh1 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_TOZERO_INV)

images_row1 = np.hstack([image_gray_blurred, thresh1, thresh2])
images_row2 = np.hstack([thresh3, thresh4, thresh5])
images_combined = np.vstack((images_row1, images_row2))

# %%
cv2.imshow('Images', image )

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
cv2.imshow('Images', image_gray )

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
cv2.imshow('Images', images_combined )

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
class ShapeDetector:

    def __init__(self):

        pass

    def detect(self, c):
    # initialize the shape name and approximate the contour

        shape = "unidentified"
        peri = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.04 * peri, True)
        
        # if the shape is a triangle, it will have 3 vertices
        if len(approx) == 3:
            shape = "triangle"

        # if the shape has 4 vertices, it is either a square or

        # a rectangle
        elif len(approx) == 4:

            # compute the bounding box of the contour and use the
            # bounding box to compute the aspect ratio
            (x, y, w, h) = cv2.boundingRect(approx)
            ar = w / float(h)

            # a square will have an aspect ratio that is approximately
            # equal to one, otherwise, the shape is a rectangle
            shape = "square" if ar >= 0.95 and ar <= 1.05 else "rectangle"



        # if the shape is a pentagon, it will have 5 vertices
        elif len(approx) == 5:
            shape = "pentagon"

        # otherwise, we assume the shape is a circle
        else:
            shape = "circle"

        # return the name of the shape
        return shape

# %%
sd = ShapeDetector()
cnts = cv2.findContours(thresh1.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if imutils.is_cv2() else cnts[1]
count = 0

# %%
len(cnts)
# Out:
# 3

# %%
for c in cnts:

    if sd.detect(c) != 'unidentified': next

    c = c.astype("float")
    c = c.astype("int")
    x,y,w,h = cv2.boundingRect(c)

#     cv2.rectangle(thresh2,(x,y),(x+w,y+h),(3,255,4),2)
#     cv2.imshow("image", image)
#     cv2.waitKey(0)

# cv2.destroyAllWindows()

#     if not (55 < w < 75 and 80 < h < 95): 

#         print("skip " + str(w) + " - " + str(h))

#         continue

    count = count+1

    cv2.imwrite("output/Img"+str(count)+".jpg", image[y: y + h, x: x + w])
    print("생성")
# Out:
# 생성
# 생성
# 생성

# %%
import os
path = '2nd/data/train/2/'
filelist = os.listdir(path)
filelist
# Out:
# ['face_1009.png',
#  'face_101.png',
#  'face_1016.png',
#  'face_1027.png',
#  'face_1039.png',
#  'face_1055.png',
#  'face_1056.png',
#  'face_1059.png',
#  'face_1060.png',
#  'face_1079.png',
#  'face_1080.png',
#  'face_1084.png',
#  'face_1089.png',
#  'face_1118.png',
#  'face_1121.png',
#  'face_1147.png',
#  'face_115.png',
#  'face_1155.png',
#  'face_116.png',
#  'face_1181.png',
#  'face_1203.png',
#  'face_121.png',
#  'face_1223.png',
#  'face_1227.png',
#  'face_1253.png',
#  'face_1273.png',
#  'face_1275.png',
#  'face_1282.png',
#  'face_1289.png',
#  'face_1298.png',
#  'face_13.png',
#  'face_1310.png',
#  'face_1332.png',
#  'face_1340.png',
#  'face_1350.png',
#  'face_1351.png',
#  'face_1354.png',
#  'face_1363.png',
#  'face_1368.png',
#  'face_137.png',
#  'face_1377.png',
#  'face_1399.png',
#  'face_1449.png',
#  'face_1453.png',
#  'face_1456.png',
#  'face_1459.png',
#  'face_1477.png',
#  'face_1480.png',
#  'face_1508.png',
#  'face_1535.png',
#  'face_1579.png',
#  'face_1586.png',
#  'face_159.png',
#  'face_1607.png',
#  'face_1609.png',
#  'face_1622.png',
#  'face_1640.png',
#  'face_1641.png',
#  'face_1643.png',
#  'face_1645.png',
#  'face_1685.png',
#  'face_1707.png',
#  'face_1708.png',
#  'face_1709.png',
#  'face_1710.png',
#  'face_1741.png',
#  'face_1744.png',
#  'face_1765.png',
#  'face_1777.png',
#  'face_1808.png',
#  'face_1841.png',
#  'face_1899.png',
#  'face_1911.png',
#  'face_1912.png',
#  'face_1917.png',
#  'face_1922.png',
#  'face_1935.png',
#  'face_1939.png',
#  'face_1947.png',
#  'face_196.png',
#  'face_1967.png',
#  'face_1981.png',
#  'face_1983.png',
#  'face_1996.png',
#  'face_2011.png',
#  'face_2014.png',
#  'face_2034.png',
#  'face_2071.png',
#  'face_2083.png',
#  'face_2090.png',
#  'face_2094.png',
#  'face_2105.png',
#  'face_2124.png',
#  'face_2128.png',
#  'face_2142.png',
#  'face_2145.png',
#  'face_215.png',
#  'face_2165.png',
#  'face_2167.png',
#  'face_2180.png',
#  'face_219.png',
#  'face_2191.png',
#  'face_22.png',
#  'face_244.png',
#  'face_252.png',
#  'face_307.png',
#  'face_310.png',
#  'face_333.png',
#  'face_337.png',
#  'face_346.png',
#  'face_367.png',
#  'face_374.png',
#  'face_388.png',
#  'face_395.png',
#  'face_398.png',
#  'face_428.png',
#  'face_454.png',
#  'face_468.png',
#  'face_479.png',
#  'face_491.png',
#  'face_554.png',
#  'face_575.png',
#  'face_589.png',
#  'face_59.png',
#  'face_593.png',
#  'face_603.png',
#  'face_604.png',
#  'face_61.png',
#  'face_625.png',
#  'face_640.png',
#  'face_644.png',
#  'face_651.png',
#  'face_672.png',
#  'face_677.png',
#  'face_71.png',
#  'face_725.png',
#  'face_73.png',
#  'face_733.png',
#  'face_738.png',
#  'face_748.png',
#  'face_757.png',
#  'face_768.png',
#  'face_794.png',
#  'face_809.png',
#  'face_81.png',
#  'face_815.png',
#  'face_816.png',
#  'face_823.png',
#  'face_830.png',
#  'face_832.png',
#  'face_871.png',
#  'face_872.png',
#  'face_873.png',
#  'face_877.png',
#  'face_879.png',
#  'face_880.png',
#  'face_887.png',
#  'face_897.png',
#  'face_906.png',
#  'face_914.png',
#  'face_987.png']

# %%
for filename in filelist:
    image = cv2.imread(path + filename)

    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image_gray_blurred = cv2.GaussianBlur(image_gray, (5, 5), 0)

    ret,thresh1 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_BINARY)
    ret,thresh2 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_BINARY_INV)
    ret,thresh3 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_TRUNC)
    ret,thresh4 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_TOZERO)
    ret,thresh5 = cv2.threshold(image_gray_blurred,127,255,cv2.THRESH_TOZERO_INV)

    images_row1 = np.hstack([image_gray_blurred, thresh1, thresh2])
    images_row2 = np.hstack([thresh3, thresh4, thresh5])
    images_combined = np.vstack((images_row1, images_row2))

    # cv2.imshow('Images', image )

    # cv2.waitKey(0)

    # cv2.destroyAllWindows()

    # cv2.imshow('Images', image_gray )

    # cv2.waitKey(0)

    # cv2.destroyAllWindows()

#     cv2.imshow('Images', images_combined )

#     cv2.waitKey(0)

#     cv2.destroyAllWindows()

    class ShapeDetector:

        def __init__(self):

            pass

        def detect(self, c):
        # initialize the shape name and approximate the contour

            shape = "unidentified"
            peri = cv2.arcLength(c, True)
            approx = cv2.approxPolyDP(c, 0.04 * peri, True)

            # if the shape is a triangle, it will have 3 vertices
            if len(approx) == 3:
                shape = "triangle"

            # if the shape has 4 vertices, it is either a square or

            # a rectangle
            elif len(approx) == 4:

                # compute the bounding box of the contour and use the
                # bounding box to compute the aspect ratio
                (x, y, w, h) = cv2.boundingRect(approx)
                ar = w / float(h)

                # a square will have an aspect ratio that is approximately
                # equal to one, otherwise, the shape is a rectangle
                shape = "square" if ar >= 0.95 and ar <= 1.05 else "rectangle"



            # if the shape is a pentagon, it will have 5 vertices
            elif len(approx) == 5:
                shape = "pentagon"

            # otherwise, we assume the shape is a circle
            else:
                shape = "circle"

            # return the name of the shape
            return shape

    sd = ShapeDetector()
    cnts = cv2.findContours(thresh2.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if imutils.is_cv2() else cnts[1]
    count = 0

    len(cnts)

    for c in cnts:

        if sd.detect(c) != 'pentagon': next

        c = c.astype("float")
        c = c.astype("int")
        x,y,w,h = cv2.boundingRect(c)

    #     cv2.rectangle(thresh2,(x,y),(x+w,y+h),(3,255,4),2)
    #     cv2.imshow("image", image)
    #     cv2.waitKey(0)

    # cv2.destroyAllWindows()

        if (w < 50 and h < 50): 

            print("skip " + str(w) + " - " + str(h))

            continue

        count = count+1

        cv2.imwrite("output/Img"+filename + str(count)+".jpg", image[y: y + h, x: x + w])
        print("생성")
# Out:
# skip 4 - 7
# skip 13 - 13
# skip 4 - 4
# skip 3 - 3
# skip 8 - 18
# skip 16 - 20
# skip 4 - 4
# skip 8 - 4
# 생성
# skip 7 - 10
# 생성
# skip 40 - 28
# skip 3 - 2
# skip 2 - 3
# skip 8 - 16
# skip 2 - 3
# 생성
# skip 2 - 1
# skip 19 - 28
# 생성
# 생성
# skip 9 - 6
# skip 2 - 3
# skip 4 - 5
# 생성
# skip 1 - 2
# 생성
# skip 3 - 7
# skip 7 - 5
# skip 1 - 2
# skip 7 - 10
# skip 1 - 2
# skip 7 - 7
# skip 13 - 6
# skip 12 - 5
# skip 3 - 4
# skip 5 - 2
# skip 4 - 4
# skip 1 - 1
# skip 8 - 4
# 생성
# skip 31 - 30
# skip 11 - 4
# skip 12 - 7
# skip 1 - 5
# skip 3 - 2
# skip 2 - 4
# skip 11 - 8
# skip 22 - 14
# 생성
# skip 7 - 10
# skip 3 - 5
# skip 5 - 9
# skip 5 - 15
# skip 3 - 2
# skip 3 - 1
# 생성
# skip 37 - 32
# skip 7 - 11
# skip 12 - 23
# skip 3 - 7
# skip 31 - 24
# skip 11 - 14
# skip 11 - 19
# 생성
# skip 8 - 6
# 생성
# 생성
# skip 6 - 9
# skip 4 - 5
# skip 2 - 2
# skip 16 - 6
# skip 9 - 8
# skip 12 - 5
# skip 16 - 16
# 생성
# skip 8 - 2
# skip 2 - 2
# skip 3 - 2
# skip 5 - 24
# skip 3 - 2
# 생성
# skip 1 - 2
# skip 2 - 4
# skip 3 - 3
# skip 2 - 3
# skip 16 - 15
# skip 1 - 2
# skip 2 - 3
# skip 4 - 6
# skip 14 - 14
# skip 12 - 18
# 생성
# skip 3 - 2
# skip 4 - 3
# skip 4 - 3
# skip 2 - 2
# skip 7 - 4
# skip 10 - 5
# skip 1 - 1
# skip 3 - 6
# skip 11 - 9
# skip 4 - 2
# 생성
# skip 5 - 2
# skip 26 - 4
# skip 2 - 2
# skip 9 - 4
# skip 11 - 11
# skip 35 - 43
# skip 5 - 13
# skip 3 - 5
# 생성
# skip 4 - 3
# skip 5 - 2
# skip 39 - 13
# skip 20 - 7
# skip 24 - 16
# skip 2 - 2
# skip 4 - 2
# skip 1 - 1
# skip 13 - 13
# 생성
# skip 15 - 7
# skip 14 - 12
# skip 29 - 33
# skip 3 - 2
# skip 1 - 1
# 생성
# skip 3 - 2
# skip 1 - 1
# skip 8 - 7
# skip 4 - 4
# skip 5 - 7
# skip 4 - 2
# skip 12 - 15
# 생성
# 생성
# 생성
# 생성
# skip 3 - 3
# skip 5 - 3
# skip 19 - 11
# skip 2 - 2
# skip 3 - 1
# skip 1 - 1
# skip 3 - 2
# skip 23 - 14
# 생성
# 생성
# skip 12 - 4
# skip 28 - 7
# skip 16 - 6
# skip 4 - 1
# 생성
# skip 20 - 19
# 생성
# 생성
# 생성
# 생성
# 생성
# 생성
# skip 1 - 2
# 생성
# skip 5 - 2
# skip 5 - 4
# skip 3 - 5
# skip 9 - 19
# skip 11 - 6
# 생성
# skip 3 - 2
# 생성
# skip 2 - 3
# skip 2 - 2
# skip 6 - 3
# 생성
# 생성
# skip 3 - 3
# skip 4 - 7
# skip 7 - 14
# skip 18 - 10
# skip 4 - 2
# 생성
# skip 27 - 25
# skip 15 - 12
# skip 5 - 9
# 생성
# skip 8 - 2
# skip 17 - 14
# 생성
# skip 2 - 5
# skip 28 - 15
# skip 14 - 7
# 생성
# skip 3 - 4
# 생성
# skip 6 - 5
# skip 6 - 4
# skip 4 - 3
# skip 3 - 3
# skip 9 - 5
# skip 3 - 3
# skip 6 - 10
# 생성
# skip 4 - 7
# 생성
# 생성
# 생성
# 생성
# skip 1 - 1
# skip 1 - 2
# skip 2 - 3
# skip 2 - 3
# skip 2 - 3
# skip 5 - 6
# skip 10 - 4
# 생성
# skip 2 - 3
# skip 13 - 13
# skip 1 - 1
# 생성
# skip 4 - 5
# skip 4 - 7
# skip 12 - 15
# skip 21 - 15
# skip 8 - 3
# skip 11 - 6
# 생성
# skip 25 - 18
# 생성
# 생성
# skip 4 - 9
# skip 7 - 3
# skip 34 - 7
# skip 18 - 6
# skip 1 - 3
# skip 1 - 3
# skip 5 - 1
# skip 3 - 5
# skip 2 - 1
# 생성
# skip 17 - 13
# 생성
# 생성
# 생성
# skip 2 - 2
# skip 4 - 2
# 생성
# 생성
# skip 5 - 4
# 생성
# skip 5 - 2
# skip 3 - 2
# skip 1 - 2
# skip 3 - 4
# skip 2 - 2
# skip 6 - 7
# skip 2 - 2
# skip 10 - 12
# skip 2 - 2
# skip 3 - 12
# skip 4 - 2
# skip 2 - 1
# skip 5 - 4
# 생성
# skip 3 - 3
# skip 13 - 20
# skip 5 - 2
# skip 13 - 7
# skip 2 - 2
# skip 3 - 2
# 생성
# 생성
# skip 2 - 4
# 생성
# skip 6 - 14
# skip 1 - 1
# skip 5 - 4
# 생성
# 생성
# 생성
# skip 1 - 1
# 생성
# skip 11 - 8
# skip 1 - 1
# skip 25 - 25
# skip 2 - 2
# 생성
# 생성
# skip 1 - 1
# skip 39 - 26
# skip 8 - 4
# skip 34 - 7
# skip 19 - 7
# 생성
# skip 3 - 7
# 생성
# skip 5 - 7
# skip 6 - 7
# 생성
# skip 2 - 2
# skip 2 - 3
# skip 2 - 2
# skip 11 - 16
# 생성
# skip 2 - 15
# skip 28 - 20
# skip 6 - 6
# skip 4 - 4
# skip 14 - 17
# skip 8 - 14
# skip 14 - 5
# 생성
# skip 3 - 2
# skip 28 - 19
# skip 27 - 18
# skip 4 - 4
# skip 11 - 8
# 생성
# skip 3 - 1
# skip 7 - 14
# 생성
# skip 4 - 3
# skip 4 - 2
# skip 13 - 11
# 생성
# skip 24 - 15
# skip 2 - 1
# skip 8 - 8
# skip 10 - 6
# skip 1 - 2
# skip 5 - 4
# skip 3 - 3
# skip 17 - 18
# 생성
# skip 2 - 2
# skip 1 - 2
# skip 24 - 19
# skip 27 - 20
# 생성
# skip 1 - 2
# skip 1 - 1
# skip 15 - 17
# skip 5 - 4
# skip 3 - 2
# 생성
# 생성
# skip 3 - 2
# skip 12 - 18
# skip 2 - 1
# skip 2 - 2
# skip 25 - 19
# 생성
# 생성
# 생성
# skip 11 - 21
# skip 23 - 24
# skip 17 - 38
# 생성
# 생성
# skip 2 - 1
# skip 2 - 2
# skip 2 - 5
# skip 2 - 2
# skip 2 - 2
# skip 3 - 4
# 생성
# skip 3 - 2
# skip 4 - 13
# skip 6 - 14
# skip 2 - 3
# skip 2 - 3
# skip 9 - 14
# skip 2 - 4
# skip 10 - 13
# skip 30 - 17
# skip 1 - 1
# skip 14 - 21
# 생성
# skip 12 - 9
# 생성
# skip 7 - 10
# skip 31 - 13
# skip 14 - 38
# skip 5 - 6
# skip 3 - 4
# skip 4 - 2
# 생성
# 생성
# skip 4 - 5
# skip 2 - 1
# skip 5 - 2
# skip 3 - 2
# 생성
# skip 26 - 16
# 생성
# skip 6 - 1
# 생성
# 생성
# skip 8 - 7
# skip 3 - 2
# 생성
# skip 1 - 1
# skip 2 - 3
# skip 3 - 10
# skip 14 - 2
# 생성
# 생성
# 생성
# skip 2 - 13
# 생성
# 생성
# skip 10 - 12
# 생성
# skip 3 - 9
# skip 13 - 4
# 생성
# skip 1 - 1
# 생성
# skip 4 - 6
# skip 7 - 10
# skip 9 - 12
# skip 7 - 9
# 생성
# skip 6 - 12
# skip 26 - 20
# skip 4 - 5
# skip 5 - 5
# skip 3 - 6
# skip 46 - 36
# skip 2 - 2
# skip 3 - 2
# skip 19 - 14
# skip 9 - 3
# skip 2 - 2
# skip 1 - 2
# 생성
# skip 3 - 6
# skip 21 - 8
# skip 13 - 3
# skip 4 - 13
# skip 39 - 23
# skip 32 - 30
# skip 9 - 3
# skip 11 - 5
# skip 9 - 5
# skip 6 - 12
# skip 36 - 34
# skip 4 - 12
# skip 1 - 2
# skip 5 - 15
# 생성
# skip 6 - 5
# skip 34 - 49
# skip 2 - 3
# skip 2 - 1
# skip 19 - 15
# skip 3 - 2
# 생성
# skip 47 - 22
# skip 17 - 23
# skip 21 - 23
# skip 9 - 6
# skip 8 - 6
# skip 40 - 8
# skip 3 - 2
# skip 15 - 9
# 생성
# skip 6 - 3
# 생성
# skip 2 - 3
# skip 4 - 7
# 생성
# skip 15 - 7
# skip 12 - 16
# 생성
# skip 5 - 4
# skip 1 - 1
# skip 5 - 3
# skip 5 - 5
# skip 8 - 3
# skip 8 - 3
# skip 1 - 1
# skip 2 - 1
# skip 8 - 5
# skip 1 - 1
# skip 1 - 1
# skip 5 - 8
# 생성
# skip 19 - 23
# skip 4 - 3
# skip 12 - 9
# 생성
# skip 30 - 12
# skip 33 - 15
# skip 2 - 2
# skip 1 - 1
# 생성
# skip 7 - 3
# skip 8 - 9
# skip 17 - 46
# skip 5 - 5
# skip 3 - 2
# skip 2 - 2
# 생성
# skip 18 - 6
# skip 11 - 6
# 생성
# skip 10 - 8
# skip 13 - 13
# skip 8 - 9
# 생성
# skip 39 - 34
# 생성
# skip 12 - 7
# skip 17 - 7
# skip 18 - 4
# skip 5 - 2
# skip 1 - 2
# skip 7 - 6
# skip 4 - 6
# 생성
# skip 2 - 1
# 생성
# skip 26 - 3
# 생성
# skip 9 - 14
# skip 2 - 3
# skip 21 - 23
# 생성
# skip 2 - 7
# skip 2 - 3
# skip 2 - 7
# skip 4 - 5
# skip 1 - 1
# 생성
# 생성
# skip 2 - 1
# skip 2 - 1
# skip 4 - 3
# skip 1 - 1
# skip 4 - 3
# skip 18 - 12
# skip 2 - 1
# skip 2 - 1
# 생성
# skip 14 - 5
# skip 11 - 9
# skip 1 - 2
# skip 2 - 1
# skip 25 - 24
# 생성
# skip 3 - 7
# 생성
# skip 17 - 4
# skip 2 - 1
# skip 2 - 4
# skip 1 - 3
# skip 25 - 11
# skip 15 - 5
# skip 7 - 3
# skip 1 - 2
# 생성
# skip 10 - 12
# skip 2 - 4
# 생성
# skip 4 - 8
# skip 9 - 11
# skip 2 - 4
# skip 2 - 2
# 생성
# skip 23 - 15
# skip 14 - 11
# 생성
# skip 6 - 1
# skip 7 - 6
# skip 5 - 5
# 생성
# 생성
# 생성
# skip 2 - 2
# 생성
# 생성
# skip 3 - 2
# skip 3 - 2
# skip 18 - 19
# 생성
# skip 3 - 3
# skip 5 - 1
# skip 3 - 2
# skip 6 - 7
# 생성
# skip 14 - 29
# skip 8 - 12
# skip 2 - 3
# 생성
# skip 2 - 2
# skip 2 - 1
# 생성
# skip 4 - 6
# skip 6 - 20
# skip 15 - 43
# 생성
# 생성
# 생성
# skip 20 - 7
# skip 5 - 8
# 생성
# 생성
# 생성
# skip 3 - 2
# 생성
# 생성
# skip 3 - 3
# 생성
# 생성
# 생성
# skip 10 - 3
# skip 2 - 2
# skip 31 - 11
# skip 7 - 5
# skip 12 - 16
# skip 4 - 1
# skip 16 - 22
# skip 2 - 2
# skip 25 - 16
# 생성
# skip 10 - 20
# skip 2 - 1
# skip 3 - 3
# skip 1 - 2
# skip 17 - 12
# 생성
# skip 4 - 4
# skip 4 - 11
# skip 5 - 3
# skip 11 - 17
# skip 7 - 12
# skip 9 - 3
# skip 9 - 17
# skip 26 - 4
# skip 3 - 2
# skip 4 - 2
# skip 2 - 3
# skip 1 - 1
# skip 1 - 2
# 생성
# skip 44 - 24
# skip 2 - 1
# skip 4 - 3
# skip 17 - 5
# skip 16 - 3
# 생성
# skip 7 - 7
# skip 3 - 2
# skip 16 - 28
# skip 8 - 5
# skip 6 - 5
# 생성
# skip 1 - 1
# skip 4 - 5
# skip 1 - 2
# 생성
# skip 4 - 6
# skip 3 - 2
# skip 7 - 8
# skip 1 - 1
# skip 3 - 2
# skip 2 - 2
# skip 23 - 15
# 생성
# skip 13 - 4
# skip 33 - 8
# 생성
# skip 9 - 5
# skip 15 - 15
# skip 1 - 2
# skip 2 - 2
# skip 2 - 2
# skip 1 - 4
# 생성
# skip 25 - 27
# skip 3 - 29
# skip 5 - 5
# skip 2 - 5
# skip 1 - 1
# skip 1 - 1
# 생성
# skip 2 - 1
# skip 1 - 1
# skip 15 - 6
# skip 11 - 7
# skip 8 - 8
# skip 7 - 8
# skip 23 - 8
# skip 5 - 7
# skip 2 - 2
# skip 22 - 12
# skip 1 - 1
# 생성
# skip 28 - 15
# skip 16 - 7
# skip 2 - 2
# skip 19 - 8
# skip 17 - 4
# 생성
# skip 1 - 1
# skip 1 - 1
# 생성
# skip 12 - 8
# skip 4 - 2
# skip 2 - 2
# skip 3 - 1
# 생성
# 생성
# skip 9 - 3
# skip 4 - 3
# skip 5 - 6
# skip 2 - 2
# skip 1 - 1
# skip 3 - 9
# skip 4 - 2
# skip 15 - 33
# skip 19 - 35
# skip 2 - 1
# skip 3 - 2
# skip 1 - 1
# skip 7 - 9
# skip 18 - 46
# skip 1 - 4
# skip 1 - 4
# skip 4 - 1
# 생성
# skip 2 - 1
# 생성
# 생성
# 생성
# skip 2 - 5
# skip 8 - 13
# skip 6 - 15
# skip 12 - 17
# skip 1 - 1
# skip 3 - 4
# skip 3 - 4
# 생성
# skip 4 - 13
# 생성
# skip 2 - 3
# skip 4 - 6
# 생성
# skip 2 - 3
# 생성
# skip 1 - 1
# skip 10 - 11
# 생성
# 생성
# 생성
# 생성
# skip 1 - 1
# skip 32 - 32
# skip 30 - 10
# skip 10 - 8
# 생성
# 생성
# skip 3 - 2
# 생성
# 생성
# skip 3 - 4
# skip 1 - 2
# skip 1 - 1
# skip 2 - 1
# 생성
